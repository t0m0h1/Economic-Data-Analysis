# %% [markdown]
# Import data using FRED API

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Set the default style and display options
plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 500)
palette = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# Combine datasets using pd.concat()

# %%
import pandas as pd

# Load datasets
corruption = pd.read_csv('datasets/corruption.csv')
cost_of_living = pd.read_csv('datasets/cost_of_living.csv')
richest_countries = pd.read_csv('datasets/richest_countries.csv')
tourism = pd.read_csv('datasets/tourism.csv')
unemployment = pd.read_csv('datasets/unemployment.csv')

# Combine all datasets into one
df = pd.concat([corruption, cost_of_living, richest_countries, tourism, unemployment], ignore_index=True)

# Display first few rows
df.head(40)
# Out:
#                  country  annual_income  corruption_index  cost_index  \
# 0                Denmark        68110.0              12.0         NaN
# 1                Finland        53660.0              12.0         NaN
# 2            New Zealand        45340.0              12.0         NaN
# 3                 Norway        84090.0              15.0         NaN
# 4              Singapore        64010.0              15.0         NaN
# 5                 Sweden        58890.0              15.0         NaN
# 6            Switzerland        90360.0              16.0         NaN
# 7            Netherlands        56370.0              18.0         NaN
# 8             Luxembourg        81110.0              19.0         NaN
# 9                Germany        51040.0              20.0         NaN
# 10        United Kingdom        45380.0              22.0         NaN
# 11             Hong Kong        54450.0              24.0         NaN
# ...

# %%
# Display the number of rows and columns and other summary statistics
print(f'The dataset has {df.shape[0]} rows and {df.shape[1]} columns.')
print(df.info())
# Out:
# The dataset has 372 rows and 12 columns.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 372 non-null    object
#  1   annual_income           110 non-null    float64
#  2   corruption_index        110 non-null    float64
#  3   cost_index              107 non-null    float64
#  4   monthly_income          107 non-null    float64
#  5   purchasing_power_index  107 non-null    float64
#  6   gdp_per_capita          50 non-null     float64
#  7   tourists_in_millions    41 non-null     float64
#  8   receipts_in_billions    41 non-null     float64
#  9   receipts_per_tourist    41 non-null     float64
#  10  percentage_of_gdp       41 non-null     float64
#  11  unemployment_rate       64 non-null     float64
# dtypes: float64(11), object(1)
# memory usage: 35.0+ KB
# None

# %%
# Check for NaN values in the dataframe
df.isna().sum()
# Out:
# country                     0
# annual_income             262
# corruption_index          262
# cost_index                265
# monthly_income            265
# purchasing_power_index    265
# gdp_per_capita            322
# tourists_in_millions      331
# receipts_in_billions      331
# receipts_per_tourist      331
# percentage_of_gdp         331
# unemployment_rate         308
# dtype: int64
